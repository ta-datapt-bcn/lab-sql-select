# %% [markdown]
# # Lab | SQL Select

# %% [markdown]
# ## Challenge 1 - Who Have Published What At Where?

# %%
#Loading SQL.

# %load_ext sql

# %%
#Accediendo a nuestra base de datos.

# %sql sqlite:///publications.db
# Out:
# 'Connected: @publications.db'

# %%
# %%sql
# select ta.au_id as author_id, au.au_lname as last_name, au.au_fname as first_name, t.title, pub.pub_name as publisher
# from titleauthor ta
# inner join authors au on ta.au_id = au.au_id
# inner join titles t on ta.title_id = t.title_id
# inner join publishers pub on pub.pub_id = t.pub_id
# Out:
#  * sqlite:///publications.db
# Done.
# [('172-32-1176', 'White', 'Johnson', 'Prolonged Data Deprivation: Four Case Studies', 'New Moon Books'),
#  ('213-46-8915', 'Green', 'Marjorie', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('213-46-8915', 'Green', 'Marjorie', 'You Can Combat Computer Stress!', 'New Moon Books'),
#  ('238-95-7766', 'Carson', 'Cheryl', 'But Is It User Friendly?', 'Algodata Infosystems'),
#  ('267-41-2394', "O'Leary", 'Michael', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems'),
#  ('267-41-2394', "O'Leary", 'Michael', 'Sushi, Anyone?', 'Binnet & Hardley'),
#  ('274-80-9391', 'Straight', 'Dean', 'Straight Talk About Computers', 'Algodata Infosystems'),
#  ('409-56-7008', 'Bennet', 'Abraham', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('427-17-2319', 'Dull', 'Ann', 'Secrets of Silicon Valley', 'Algodata Infosystems'),
# ...

# %%
#Inicialmente tenía un conflicto con dos variables del mismo nombre (au_id) en tablas separadas, pero tras un reinicio 
#ha desaparecido. Misterios de SQL.

# %% [markdown]
# ## Challenge 2 - Who Have Published How Many At Where?

# %% [markdown]
# Podemos aprovechar el código del primer apartado simplemente añadiendo una nueva columna en la que volcaremos el output de un *count* y finalmente obteniendo el conteo mediante *groupby*.

# %%
# %%sql
# select ta.au_id as author_id, au.au_lname as last_name, au.au_fname as first_name, t.title, pub.pub_name as publisher, count(t.title) as title_count
# from titleauthor ta
# inner join authors au on ta.au_id = au.au_id
# inner join titles t on ta.title_id = t.title_id
# inner join publishers pub on pub.pub_id = t.pub_id
# group by author_id
# Out:
#  * sqlite:///publications.db
# Done.
# [('172-32-1176', 'White', 'Johnson', 'Prolonged Data Deprivation: Four Case Studies', 'New Moon Books', 1),
#  ('213-46-8915', 'Green', 'Marjorie', "The Busy Executive's Database Guide", 'Algodata Infosystems', 2),
#  ('238-95-7766', 'Carson', 'Cheryl', 'But Is It User Friendly?', 'Algodata Infosystems', 1),
#  ('267-41-2394', "O'Leary", 'Michael', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems', 2),
#  ('274-80-9391', 'Straight', 'Dean', 'Straight Talk About Computers', 'Algodata Infosystems', 1),
#  ('409-56-7008', 'Bennet', 'Abraham', "The Busy Executive's Database Guide", 'Algodata Infosystems', 1),
#  ('427-17-2319', 'Dull', 'Ann', 'Secrets of Silicon Valley', 'Algodata Infosystems', 1),
#  ('472-27-2349', 'Gringlesby', 'Burt', 'Sushi, Anyone?', 'Binnet & Hardley', 1),
#  ('486-29-1786', 'Locksley', 'Charlene', 'Net Etiquette', 'Algodata Infosystems', 2),
# ...

# %% [markdown]
# ## Challenge 3 - Best Selling Authors

# %% [markdown]
# Aprovechando la tabla de autores previamente creada ejecutamos un join con la tabla *sales*, a través del cual podremos obtener el número de ventas por autor. Después procedemos a ordenar la tabla por ventas y mostramos sólo los 3 autores top.

# %%
# %%sql
# select ta.au_id as author_id, au.au_lname as last_name, au.au_fname as first_name, sum(s.qty) as total
# from titleauthor ta
# inner join authors au on ta.au_id = au.au_id
# inner join sales s on s.title_id = ta.title_id
# group by author_id
# order by total desc
# limit 3
# Out:
#  * sqlite:///publications.db
# Done.
# [('899-46-2035', 'Ringer', 'Anne', 148),
#  ('998-72-3567', 'Ringer', 'Albert', 133),
#  ('213-46-8915', 'Green', 'Marjorie', 50)]

# %% [markdown]
# <div align="right">Ironhack DA PT 2021</div>
#
# <div align="right">Xavier Esteban</div>
